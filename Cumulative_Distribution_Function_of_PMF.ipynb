# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanRajput997/Statistics/blob/main/Cumulative_Distribution_Function_of_PMF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Single Dice Rolling...**

# %%
import pandas as pd

# %%
import random

# %%
L = []
for i in range(10000):
  L.append(random.randint(1,6))

# %%
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [1, 6, 3, 6, 3]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
import numpy as np
np.cumsum(s)
# Out:
# 1    0.1628
# 2    0.3263
# 3    0.4980
# 4    0.6651
# 5    0.8334
# 6    1.0000
# Name: count, dtype: float64

# %%
np.cumsum(s).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Double Dice Rolling...**

# %%
import pandas as pd

# %%
import random

# %%
L = []
for i in range(10000):
  a = random.randint(1,6)
  b = random.randint(1,6)

  L.append(a+b)

# %%
len(L)
# Out:
# 10000

# %%
L[:5]
# Out:
# [9, 5, 12, 7, 8]

# %%
s = (pd.Series(L).value_counts()/pd.Series(L).value_counts().sum()).sort_index()

# %%
import numpy as np
np.cumsum(s)
# Out:
# 2     0.0249
# 3     0.0760
# 4     0.1567
# 5     0.2666
# 6     0.4045
# 7     0.5729
# 8     0.7183
# 9     0.8325
# 10    0.9192
# 11    0.9745
# 12    1.0000
# Name: count, dtype: float64

# %%
np.cumsum(s).plot(kind='bar')
# Out:
# <Axes: >
