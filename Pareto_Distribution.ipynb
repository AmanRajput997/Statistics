# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanRajput997/Statistics/blob/main/Pareto_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Log Log Plotm

# %%
import numpy as np

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters of the Pareto distribution
alpha = 3
xm = 1

# Create an array of x values
x = np.linspace(0.1, 10, 1000)

# Calculate the y values of the Pareto distribution
y = alpha * (xm**alpha) / (x**(alpha+1))

plt.plot(x,y)

# %%
# Create the log-log plot
plt.plot(np.log(x),np.log(y))

# Add labels and a title
plt.xlabel('x')
plt.ylabel('P(x)')
plt.title('Pareto Distribution')
# Out:
# Text(0.5, 1.0, 'Pareto Distribution')

# %% [markdown]
# **QQ Plot**

# %%
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Define the praramters of the Pareto distribution
alpha = 2
xm = 1

# Generate a set of random data from the Pareto distribution
x = stats.pareto.rvs(b=alpha, scale=xm, size=1000)

# %%
plt.hist(x)
# Out:
# (array([954.,  31.,   9.,   2.,   3.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 1.00090674,  4.2192418 ,  7.43757686, 10.65591192, 13.87424698,
#         17.09258204, 20.3109171 , 23.52925216, 26.74758722, 29.96592228,
#         33.18425735]),
#  <BarContainer object of 10 artists>)

# %%
# Fit a Pareto distribution to the data
params = stats.pareto.fit(x, floc=0)

# Create a Pareto distribution object with the fitted parameters
dist = stats.pareto(b=params[0], scale=params[2])

# %%
# Create a Q plot of the data using the pareto distribution
fig = sm.qqplot(x, dist=dist, line='45')

# Add a title and labels to the plot
plt.title('QQ Plot of Pareto Distribution with Pareto Fit')
plt.xlabel('Theoreetical Quantiles')
plt.ylabel('Sample Quantiles')

# Show the plot
plt.show()
