# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanRajput997/Statistics/blob/main/Parametric_Density_Estimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal

sample = normal(loc=50, scale=5, size=1000)

# %%
sample
# Out:
# array([50.57459857, 49.52377685, 57.27821354, 39.52502064, 54.24613564,
#        46.64159835, 47.47164737, 51.09160758, 47.99778261, 59.92547555,
#        55.20435562, 53.82310142, 52.05301181, 48.41678726, 50.41213039,
#        48.23021223, 46.671361  , 50.64133472, 54.96816894, 50.87959219,
#        45.65554255, 48.16656016, 56.08817993, 51.65795658, 52.116906  ,
#        57.99286592, 47.34535958, 49.36453971, 55.78002186, 50.47300376,
#        44.05874326, 51.25411006, 45.91329989, 57.51943212, 50.84396958,
#        53.09427267, 54.31442047, 54.87829684, 45.34625097, 44.50715389,
#        51.57127887, 49.32221309, 54.81487902, 38.02006662, 45.07725684,
#        54.78902079, 50.81494838, 52.52904442, 48.6748074 , 41.84793506,
#        44.49508507, 51.82890658, 57.35207838, 45.61987883, 51.73767793,
#        53.6897688 , 48.43493733, 44.97007749, 42.76009289, 46.25017597,
#        60.42620511, 58.47751436, 45.16342436, 55.47817031, 43.76929792,
# ...

# %%
sample.mean()
# Out:
# np.float64(49.94228570086187)

# %%
# Plot histogram to understand the distribution of the data
plt.hist(sample, bins=10)
# Out:
# (array([  6.,  30.,  95., 185., 270., 217., 133.,  53.,   9.,   2.]),
#  array([34.26574249, 37.61485821, 40.96397394, 44.31308966, 47.66220539,
#         51.01132111, 54.36043684, 57.70955256, 61.05866829, 64.40778401,
#         67.75689974]),
#  <BarContainer object of 10 artists>)

# %%
# Calculate sample mean and sample std div
sample_mean = sample.mean()
sample_std = sample.std()

# %%
# Fit the distribution with the above parameters
from scipy.stats import norm
dist = norm(sample_mean, sample_std)

# %%
values = np.linspace(sample.min(), sample.max(),100)

# %%
sample.min()
# Out:
# np.float64(34.26574248934886)

# %%
sample.max()
# Out:
# np.float64(67.75689973546558)

# %%
probabilities = [dist.pdf(value) for value in values]

# %%
#Plot th histogram and pdf
plt.hist(sample,bins=10, density=True)
plt.plot(values,probabilities)

# %%
import seaborn as sns
sns.distplot(sample)
# Out:
# /tmp/ipython-input-1482356190.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample)
# <Axes: ylabel='Density'>
